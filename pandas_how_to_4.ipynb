# %% [markdown]
# <a href="https://colab.research.google.com/github/ONowakowski/howToDataInPython/blob/master/pandas_how_to_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
url = 'https://storage.googleapis.com/esmartdata-courses-files/ds-bootcamp/appstore_games.csv'
df_raw = pd.read_csv(url)
df_raw.head()
# Out:
#                                                  URL  ...  Current Version Release Date
# 0   https://apps.apple.com/us/app/sudoku/id284921427  ...                    30/05/2017
# 1  https://apps.apple.com/us/app/reversi/id284926400  ...                    17/05/2018
# 2  https://apps.apple.com/us/app/morocco/id284946595  ...                     5/09/2017
# 3  https://apps.apple.com/us/app/sudoku-free/id28...  ...                    30/05/2017
# 4  https://apps.apple.com/us/app/senet-deluxe/id2...  ...                    22/07/2018
#
# [5 rows x 18 columns]

# %%
df_raw.columns
# Out:
# Index(['URL', 'ID', 'Name', 'Subtitle', 'Icon URL', 'Average User Rating',
#        'User Rating Count', 'Price', 'In-app Purchases', 'Description',
#        'Developer', 'Age Rating', 'Languages', 'Size', 'Primary Genre',
#        'Genres', 'Original Release Date', 'Current Version Release Date'],
#       dtype='object')

# %%
#warto pracowac na kopii obiektu, by moc zawsze wrocic do oryginalu
df = df_raw.copy()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17007 entries, 0 to 17006
# Data columns (total 18 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   URL                           17007 non-null  object
#  1   ID                            17007 non-null  int64
#  2   Name                          17007 non-null  object
#  3   Subtitle                      5261 non-null   object
#  4   Icon URL                      17007 non-null  object
#  5   Average User Rating           7561 non-null   float64
#  6   User Rating Count             7561 non-null   float64
#  7   Price                         16983 non-null  float64
#  8   In-app Purchases              7683 non-null   object
#  9   Description                   17007 non-null  object
#  10  Developer                     17007 non-null  object
#  11  Age Rating                    17007 non-null  object
# ...

# %%
#usuwam niepotrzebne kolumny
df = df.drop(columns=['URL', 'Subtitle', 'Icon URL', 'In-app Purchases', 'Description'])
df.head()
# Out:
#           ID           Name  ...  Original Release Date  Current Version Release Date
# 0  284921427         Sudoku  ...             11/07/2008                    30/05/2017
# 1  284926400        Reversi  ...             11/07/2008                    17/05/2018
# 2  284946595        Morocco  ...             11/07/2008                     5/09/2017
# 3  285755462  Sudoku (Free)  ...             23/07/2008                    30/05/2017
# 4  285831220   Senet Deluxe  ...             18/07/2008                    22/07/2018
#
# [5 rows x 13 columns]

# %%
#ustawiam ID jako indeks obiektu
df = df.set_index('ID')
df.head()
# Out:
#                     Name  ...  Current Version Release Date
# ID                        ...
# 284921427         Sudoku  ...                    30/05/2017
# 284926400        Reversi  ...                    17/05/2018
# 284946595        Morocco  ...                     5/09/2017
# 285755462  Sudoku (Free)  ...                    30/05/2017
# 285831220   Senet Deluxe  ...                    22/07/2018
#
# [5 rows x 12 columns]

# %%
df.describe().T #opis danych numerycznych
# Out:
#                        count          mean  ...          75%           max
# Average User Rating   7561.0  4.060905e+00  ...          4.5  5.000000e+00
# User Rating Count     7561.0  3.306531e+03  ...        309.0  3.032734e+06
# Price                16983.0  8.134187e-01  ...          0.0  1.799900e+02
# Size                 17006.0  1.157064e+08  ...  133027072.0  4.005591e+09
#
# [4 rows x 8 columns]

# %%
df.describe(include=['object']).T #opis danych tekstowych
# Out:
#                               count  ...   freq
# Name                          17007  ...      2
# Developer                     17007  ...    123
# Age Rating                    17007  ...  11806
# Languages                     16947  ...  12467
# Primary Genre                 17007  ...  16286
# Genres                        17007  ...    778
# Original Release Date         17007  ...     75
# Current Version Release Date  17007  ...    118
#
# [8 rows x 4 columns]

# %%
#zmieniam nazwy kolumn na male litery oraz zamieniam spacje na podkreslenie
df.columns = [col.lower().replace(' ', '_') for col in df.columns]
df
# Out:
#                                  name  ...  current_version_release_date
# ID                                     ...
# 284921427                      Sudoku  ...                    30/05/2017
# 284926400                     Reversi  ...                    17/05/2018
# 284946595                     Morocco  ...                     5/09/2017
# 285755462               Sudoku (Free)  ...                    30/05/2017
# 285831220                Senet Deluxe  ...                    22/07/2018
# ...                               ...  ...                           ...
# 1474626442  Stack Puzzle : Rise Tower  ...                    30/07/2019
# 1474919257                  EachOther  ...                     1/08/2019
# 1474962324         Rabbit Vs Tortoise  ...                     3/08/2019
# 1474963671                     FaTaLL  ...                     1/08/2019
# 1475076711   The Three Kingdoms :Bomb  ...                     2/08/2019
#
# [17007 rows x 12 columns]

# %% [markdown]
# #Rozkład zmiennej

# %%
df.primary_genre
# Out:
# ID
# 284921427     Games
# 284926400     Games
# 284946595     Games
# 285755462     Games
# 285831220     Games
#               ...
# 1474626442    Games
# 1474919257    Games
# 1474962324    Games
# 1474963671    Games
# 1475076711    Games
# Name: primary_genre, Length: 17007, dtype: object

# %%
df.primary_genre.value_counts() #policzenie ile danych wartosci jest
# Out:
# Games                16286
# Education              222
# Entertainment          198
# Utilities               77
# Sports                  60
# Reference               32
# Stickers                29
# Finance                 18
# Business                16
# Productivity            15
# Lifestyle               10
# Social Networking        9
# Book                     9
# News                     7
# Health & Fitness         5
# Food & Drink             4
# Navigation               3
# Music                    3
# Medical                  2
# Travel                   1
# Shopping                 1
# Name: primary_genre, dtype: int64

# %%
df.primary_genre.value_counts().nlargest(5) #5 najwiekszych wartosci
# Out:
# Games            16286
# Education          222
# Entertainment      198
# Utilities           77
# Sports              60
# Name: primary_genre, dtype: int64

# %%
list(df.primary_genre.value_counts().nlargest(5).index)
# Out:
# ['Games', 'Education', 'Entertainment', 'Utilities', 'Sports']

# %%
#wykres wymaganego wieku
import seaborn as sns
sns.set()

df.age_rating.value_counts().plot(kind='bar')

# %%
_ = df.age_rating.value_counts().plot(kind='pie') #podkreslnik zeby nie wyswietlal sie komunikat na gorze

# %%
#chcemy dolaczyc kolumne z iloscia dostepnych jezykow w aplikacji
df.languages #jezyki sa przekazane jako tekst, oddzielone ', '
# Out:
# ID
# 284921427     DA, NL, EN, FI, FR, DE, IT, JA, KO, NB, PL, PT...
# 284926400                                                    EN
# 284946595                                                    EN
# 285755462     DA, NL, EN, FI, FR, DE, IT, JA, KO, NB, PL, PT...
# 285831220     DA, NL, EN, FR, DE, EL, IT, JA, KO, NO, PT, RU...
#                                     ...
# 1474626442                                                   EN
# 1474919257                                                   EN
# 1474962324                                                   EN
# 1474963671                                                   EN
# 1475076711                                               EN, ZH
# Name: languages, Length: 17007, dtype: object

# %%
df.languages.str.split(', ') #jezyki przedstawione jako lista
# Out:
# ID
# 284921427     [DA, NL, EN, FI, FR, DE, IT, JA, KO, NB, PL, P...
# 284926400                                                  [EN]
# 284946595                                                  [EN]
# 285755462     [DA, NL, EN, FI, FR, DE, IT, JA, KO, NB, PL, P...
# 285831220     [DA, NL, EN, FR, DE, EL, IT, JA, KO, NO, PT, R...
#                                     ...
# 1474626442                                                 [EN]
# 1474919257                                                 [EN]
# 1474962324                                                 [EN]
# 1474963671                                                 [EN]
# 1475076711                                             [EN, ZH]
# Name: languages, Length: 17007, dtype: object

# %%
df.languages.str.split(', ').str.len() #ilosc jezykow w kazdej liscie
# Out:
# ID
# 284921427     17.0
# 284926400      1.0
# 284946595      1.0
# 285755462     17.0
# 285831220     15.0
#               ...
# 1474626442     1.0
# 1474919257     1.0
# 1474962324     1.0
# 1474963671     1.0
# 1475076711     2.0
# Name: languages, Length: 17007, dtype: float64

# %%
df['num_lang'] = df.languages.str.split(', ').str.len() #stworzenie nowej kolumny
df.sample(5)
# Out:
#                                     name  ...  num_lang
# ID                                        ...
# 1259664290            Sudoku Zen Premium  ...       1.0
# 1325923640             Dungeon Builder M  ...       3.0
# 1347031162  City Frontline War Commandos  ...       1.0
# 1237587855    100 Pukky - Balloon popper  ...       1.0
# 1468722554                 Circle Blast!  ...       1.0
#
# [5 rows x 13 columns]

# %%
_ = df.num_lang.value_counts().nlargest(10).plot(kind='barh')

# %% [markdown]
# #Sprawdzanie braków danych

# %%
df.info() #tu mozna zauwazyc czy sa braki
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17007 entries, 284921427 to 1475076711
# Data columns (total 13 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   name                          17007 non-null  object
#  1   average_user_rating           7561 non-null   float64
#  2   user_rating_count             7561 non-null   float64
#  3   price                         16983 non-null  float64
#  4   developer                     17007 non-null  object
#  5   age_rating                    17007 non-null  object
#  6   languages                     16947 non-null  object
#  7   size                          17006 non-null  float64
#  8   primary_genre                 17007 non-null  object
#  9   genres                        17007 non-null  object
#  10  original_release_date         17007 non-null  object
#  11  current_version_release_date  17007 non-null  object
# ...

# %%
df.average_user_rating.value_counts() #brak zadnej informacji o braku danych
# Out:
# 4.5    2861
# 4.0    1722
# 5.0     990
# 3.5     925
# 3.0     514
# 2.5     317
# 2.0     158
# 1.5      60
# 1.0      14
# Name: average_user_rating, dtype: int64

# %%
df.average_user_rating.value_counts(dropna=False) #widzimy ile jest brakujacych
# Out:
# NaN    9446
# 4.5    2861
# 4.0    1722
# 5.0     990
# 3.5     925
# 3.0     514
# 2.5     317
# 2.0     158
# 1.5      60
# 1.0      14
# Name: average_user_rating, dtype: int64

# %%
df.isnull() #dostaniemy duza maske ktora przyjmuje True jesli jest brak w danym fragmencie
# Out:
#              name  average_user_rating  ...  current_version_release_date  num_lang
# ID                                      ...
# 284921427   False                False  ...                         False     False
# 284926400   False                False  ...                         False     False
# 284946595   False                False  ...                         False     False
# 285755462   False                False  ...                         False     False
# 285831220   False                False  ...                         False     False
# ...           ...                  ...  ...                           ...       ...
# 1474626442  False                 True  ...                         False     False
# 1474919257  False                 True  ...                         False     False
# 1474962324  False                 True  ...                         False     False
# 1474963671  False                 True  ...                         False     False
# ...

# %%
df.isnull().sum() #widzimy ile jest brakow danych w danej kolumnie
# Out:
# name                               0
# average_user_rating             9446
# user_rating_count               9446
# price                             24
# developer                          0
# age_rating                         0
# languages                         60
# size                               1
# primary_genre                      0
# genres                             0
# original_release_date              0
# current_version_release_date       0
# num_lang                          60
# dtype: int64

# %%
df = df.dropna() #usuwamy wiersze, ktore maja przynajmniej jeden brak
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7537 entries, 284921427 to 1474461379
# Data columns (total 13 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   name                          7537 non-null   object
#  1   average_user_rating           7537 non-null   float64
#  2   user_rating_count             7537 non-null   float64
#  3   price                         7537 non-null   float64
#  4   developer                     7537 non-null   object
#  5   age_rating                    7537 non-null   object
#  6   languages                     7537 non-null   object
#  7   size                          7537 non-null   float64
#  8   primary_genre                 7537 non-null   object
#  9   genres                        7537 non-null   object
#  10  original_release_date         7537 non-null   object
#  11  current_version_release_date  7537 non-null   object
# ...

# %%
import pandas as pd
import numpy as np

# %%
url = 'https://storage.googleapis.com/esmartdata-courses-files/ds-bootcamp/online_retail.xlsx'
raw_retail = pd.read_excel(url)
raw_retail.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  datetime64[ns]
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 33.1+ MB

# %%
raw_retail.head()
# Out:
#   InvoiceNo StockCode  ... CustomerID         Country
# 0    536365    85123A  ...    17850.0  United Kingdom
# 1    536365     71053  ...    17850.0  United Kingdom
# 2    536365    84406B  ...    17850.0  United Kingdom
# 3    536365    84029G  ...    17850.0  United Kingdom
# 4    536365    84029E  ...    17850.0  United Kingdom
#
# [5 rows x 8 columns]

# %%
retail = raw_retail.copy()

# %%
retail = retail.set_index('InvoiceNo')
retail.head()
# Out:
#           StockCode  ...         Country
# InvoiceNo            ...
# 536365       85123A  ...  United Kingdom
# 536365        71053  ...  United Kingdom
# 536365       84406B  ...  United Kingdom
# 536365       84029G  ...  United Kingdom
# 536365       84029E  ...  United Kingdom
#
# [5 rows x 7 columns]

# %%
retail.info() #customerId zmienimy na string
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 541909 entries, 536365 to 581587
# Data columns (total 7 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   StockCode    541909 non-null  object
#  1   Description  540455 non-null  object
#  2   Quantity     541909 non-null  int64
#  3   InvoiceDate  541909 non-null  datetime64[ns]
#  4   UnitPrice    541909 non-null  float64
#  5   CustomerID   406829 non-null  float64
#  6   Country      541909 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(3)
# memory usage: 33.1+ MB

# %%
retail.describe() #warto sie przyjrzec danym na poczatku, np. tutaj mamy niepozadane wartosci ujemne
# Out:
#             Quantity      UnitPrice     CustomerID
# count  541909.000000  541909.000000  406829.000000
# mean        9.552250       4.611114   15287.690570
# std       218.081158      96.759853    1713.600303
# min    -80995.000000  -11062.060000   12346.000000
# 25%         1.000000       1.250000   13953.000000
# 50%         3.000000       2.080000   15152.000000
# 75%        10.000000       4.130000   16791.000000
# max     80995.000000   38970.000000   18287.000000

# %%
retail.isnull().sum()
# Out:
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
retail = retail.dropna() #usuwamy wiersze z pustymi wartosciami
retail.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 406829 entries, 536365 to 581587
# Data columns (total 7 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   StockCode    406829 non-null  object
#  1   Description  406829 non-null  object
#  2   Quantity     406829 non-null  int64
#  3   InvoiceDate  406829 non-null  datetime64[ns]
#  4   UnitPrice    406829 non-null  float64
#  5   CustomerID   406829 non-null  float64
#  6   Country      406829 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(3)
# memory usage: 24.8+ MB

# %%
retail[retail.Quantity <= 0] #tyle mamy zlych wartosci w ilosci
# Out:
#           StockCode  ...         Country
# InvoiceNo            ...
# C536379           D  ...  United Kingdom
# C536383      35004C  ...  United Kingdom
# C536391       22556  ...  United Kingdom
# C536391       21984  ...  United Kingdom
# C536391       21983  ...  United Kingdom
# ...             ...  ...             ...
# C581490       23144  ...  United Kingdom
# C581499           M  ...  United Kingdom
# C581568       21258  ...  United Kingdom
# C581569       84978  ...  United Kingdom
# C581569       20979  ...  United Kingdom
#
# [8905 rows x 7 columns]

# %%
retail = retail[retail.Quantity > 0] #teraz juz mamy wszystkie wartosci Quantity wieksze od 0
retail.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 397924 entries, 536365 to 581587
# Data columns (total 7 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   StockCode    397924 non-null  object
#  1   Description  397924 non-null  object
#  2   Quantity     397924 non-null  int64
#  3   InvoiceDate  397924 non-null  datetime64[ns]
#  4   UnitPrice    397924 non-null  float64
#  5   CustomerID   397924 non-null  float64
#  6   Country      397924 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(3)
# memory usage: 24.3+ MB

# %%
#konwertujemy CustomerID na string, zeby to zrobic warto najpierw przekonwertowac na int
retail.CustomerID = retail.CustomerID.apply(lambda x: str(int(x)))
retail.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 397924 entries, 536365 to 581587
# Data columns (total 7 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   StockCode    397924 non-null  object
#  1   Description  397924 non-null  object
#  2   Quantity     397924 non-null  int64
#  3   InvoiceDate  397924 non-null  datetime64[ns]
#  4   UnitPrice    397924 non-null  float64
#  5   CustomerID   397924 non-null  object
#  6   Country      397924 non-null  object
# dtypes: datetime64[ns](1), float64(1), int64(1), object(4)
# memory usage: 24.3+ MB

# %%
#po konwersji sprawdzamy czy na pewno wszystko ok wyglada
retail.sample(5)
# Out:
#           StockCode  ...         Country
# InvoiceNo            ...
# 545045        22729  ...  United Kingdom
# 537422       84406B  ...  United Kingdom
# 566420        22940  ...  United Kingdom
# 536623        21518  ...  United Kingdom
# 567853        22171  ...  United Kingdom
#
# [5 rows x 7 columns]

# %% [markdown]
# #Porównanie do SQL

# %%
# SELECT * FROM retail;
retail
# Out:
#           StockCode  ...         Country
# InvoiceNo            ...
# 536365       85123A  ...  United Kingdom
# 536365        71053  ...  United Kingdom
# 536365       84406B  ...  United Kingdom
# 536365       84029G  ...  United Kingdom
# 536365       84029E  ...  United Kingdom
# ...             ...  ...             ...
# 581587        22613  ...          France
# 581587        22899  ...          France
# 581587        23254  ...          France
# 581587        23255  ...          France
# 581587        22138  ...          France
#
# [397924 rows x 7 columns]

# %%
# SELECT Quantity, UnitPrice, CustomerID FROM retail;
retail[['Quantity', 'UnitPrice', 'CustomerID']]
# Out:
#            Quantity  UnitPrice CustomerID
# InvoiceNo
# 536365            6       2.55      17850
# 536365            6       3.39      17850
# 536365            8       2.75      17850
# 536365            6       3.39      17850
# 536365            6       3.39      17850
# ...             ...        ...        ...
# 581587           12       0.85      12680
# 581587            6       2.10      12680
# 581587            4       4.15      12680
# 581587            4       4.15      12680
# 581587            3       4.95      12680
#
# [397924 rows x 3 columns]

# %%
# SELECT Quantity, UnitPrice, CustomerID FROM retail LIMIT 3;
retail[['Quantity', 'UnitPrice', 'CustomerID']].head(3)
# Out:
#            Quantity  UnitPrice CustomerID
# InvoiceNo
# 536365            6       2.55      17850
# 536365            6       3.39      17850
# 536365            8       2.75      17850

# %%
# SELECT * FROM retail WHERE CustomerID = '17850' 
retail[retail.CustomerID == '17850']
#retail.query('CustomerID == "17850"')
# Out:
#           StockCode  ...         Country
# InvoiceNo            ...
# 536365       85123A  ...  United Kingdom
# 536365        71053  ...  United Kingdom
# 536365       84406B  ...  United Kingdom
# 536365       84029G  ...  United Kingdom
# 536365       84029E  ...  United Kingdom
# ...             ...  ...             ...
# 536790        22752  ...  United Kingdom
# 536790        22803  ...  United Kingdom
# 536790        21730  ...  United Kingdom
# 536791        22632  ...  United Kingdom
# 536791        22633  ...  United Kingdom
#
# [297 rows x 7 columns]

# %%
# SELECT * FROM RETAIL WHERE CustomerID = '17850' AND UnitPrice > 5;
retail[(retail.CustomerID == '17850') & (retail.UnitPrice > 5)]
# Out:
#           StockCode  ...         Country
# InvoiceNo            ...
# 536365        22752  ...  United Kingdom
# 536373        82486  ...  United Kingdom
# 536373        22752  ...  United Kingdom
# 536375        82486  ...  United Kingdom
# 536375        22752  ...  United Kingdom
# 536396        82486  ...  United Kingdom
# 536396        22752  ...  United Kingdom
# 536396        22803  ...  United Kingdom
# 536406        82486  ...  United Kingdom
# 536406        22752  ...  United Kingdom
# 536406        22803  ...  United Kingdom
# 536600        82486  ...  United Kingdom
# 536600        22752  ...  United Kingdom
# 536600        22803  ...  United Kingdom
# 536602        22752  ...  United Kingdom
# 536609        82486  ...  United Kingdom
# 536609        22752  ...  United Kingdom
# 536612        82486  ...  United Kingdom
# 536628        82486  ...  United Kingdom
# 536628        22752  ...  United Kingdom
# 536630        82486  ...  United Kingdom
# ...

# %%
# SELECT * FROM RETAIL WHERE CustomerID = '17850' OR Country = 'France'
retail[(retail.CustomerID == '17850') | (retail.Country == 'France')]
# Out:
#           StockCode  ...         Country
# InvoiceNo            ...
# 536365       85123A  ...  United Kingdom
# 536365        71053  ...  United Kingdom
# 536365       84406B  ...  United Kingdom
# 536365       84029G  ...  United Kingdom
# 536365       84029E  ...  United Kingdom
# ...             ...  ...             ...
# 581587        22613  ...          France
# 581587        22899  ...          France
# 581587        23254  ...          France
# 581587        23255  ...          France
# 581587        22138  ...          France
#
# [8639 rows x 7 columns]

# %%
# SELECT * FROM retail WHERE StockCode is NOT NULL;
retail[retail.StockCode.notnull()]
# Out:
#           StockCode  ...         Country
# InvoiceNo            ...
# 536365       85123A  ...  United Kingdom
# 536365        71053  ...  United Kingdom
# 536365       84406B  ...  United Kingdom
# 536365       84029G  ...  United Kingdom
# 536365       84029E  ...  United Kingdom
# ...             ...  ...             ...
# 581587        22613  ...          France
# 581587        22899  ...          France
# 581587        23254  ...          France
# 581587        23255  ...          France
# 581587        22138  ...          France
#
# [397924 rows x 7 columns]

# %%
# SELECT CustomerID, count(*) FROM retail GROUP BY CustomerID;
# retail.CustomerID.value_counts()
retail.groupby('CustomerID').size()
# Out:
# CustomerID
# 12346      1
# 12347    182
# 12348     31
# 12349     73
# 12350     17
#         ...
# 18280     10
# 18281      7
# 18282     12
# 18283    756
# 18287     70
# Length: 4339, dtype: int64

# %%
retail.head(1)
# Out:
#           StockCode  ...         Country
# InvoiceNo            ...
# 536365       85123A  ...  United Kingdom
#
# [1 rows x 7 columns]

# %%
#tworzenie kolumny z przychodem od danej sprzedazy
retail['Revenue'] = retail.Quantity * retail.UnitPrice
retail.head()
# Out:
#           StockCode  ... Revenue
# InvoiceNo            ...
# 536365       85123A  ...   15.30
# 536365        71053  ...   20.34
# 536365       84406B  ...   22.00
# 536365       84029G  ...   20.34
# 536365       84029E  ...   20.34
#
# [5 rows x 8 columns]

# %%
# SELECT CustomerID, avg(Revenue), count(*) FROM retail GROUP BY CustomerID;
retail.groupby('CustomerID').aggregate({'Revenue': np.mean, 'CustomerID': np.size}) \
    .rename(columns={'Revenue': 'RevenueAvg', 'CustomerID': 'CustomerIDCount'}) 
  #funkcja aggregate przyjmuje slownik w ktorym mozna przypisac funkcje do danej kolumny
# Out:
#               RevenueAvg  CustomerIDCount
# CustomerID
# 12346       77183.600000                1
# 12347          23.681319              182
# 12348          57.975484               31
# 12349          24.076027               73
# 12350          19.670588               17
# ...                  ...              ...
# 18280          18.060000               10
# 18281          11.545714                7
# 18282          14.837500               12
# 18283           2.771005              756
# 18287          26.246857               70
#
# [4339 rows x 2 columns]

# %%
#tworzymy nowa kolumne -> dzien miesiaca zamowienia
retail['InvoiceDateDay'] = retail.InvoiceDate.dt.day #InvoiceDate jest typu datetime, dlatego po dt mozemy sie odwolac do funkcji
retail.head(2)
# Out:
#           StockCode  ... InvoiceDateDay
# InvoiceNo            ...
# 536365       85123A  ...              1
# 536365        71053  ...              1
#
# [2 rows x 9 columns]

# %%
# SELECT InvoiceDateDay, sum(Revenue) FROM retail GROUPBY InvoiceDateDay;
results = retail.groupby('InvoiceDateDay').aggregate({'Revenue': np.sum}).rename(columns={'Revenue': 'TotalRevenue'})
results
# Out:
#                 TotalRevenue
# InvoiceDateDay
# 1                 286370.870
# 2                 256858.750
# 3                 285430.150
# 4                 329347.220
# 5                 354033.810
# 6                 336759.840
# 7                 376788.980
# 8                 296747.450
# 9                 460216.080
# 10                325106.180
# 11                345332.090
# 12                222496.570
# 13                252007.160
# 14                337574.550
# 15                304635.811
# 16                279384.030
# 17                333157.240
# 18                367947.890
# 19                249792.310
# 20                363689.280
# 21                325954.330
# 22                250304.000
# 23                249339.690
# 24                267594.910
# 25                228150.541
# 26                184091.902
# 27                224344.430
# 28                297424.870
# 29                167977.110
# 30                202865.820
# ...

# %%
#szybki wykres
import seaborn as sns
sns.set()

_ = results.plot(kind = 'bar')

# %%
# SELECT * FROM retail ORDER BY Quantity DESC LIMIT 5;
#retail.sort_values('Quantity', ascending=False).head()
retail.nlargest(5, columns=['Quantity'])
# Out:
#           StockCode  ... InvoiceDateDay
# InvoiceNo            ...
# 581483        23843  ...              9
# 541431        23166  ...             18
# 578841        84826  ...             25
# 573008        84077  ...             27
# 554868        22197  ...             27
#
# [5 rows x 9 columns]

# %%
# SELECT * FROM retail ORDER BY Quantity LIMIT 5;
#retail.sort_values('Quantity').head()
retail.nsmallest(5, columns=['Quantity'])
# Out:
#           StockCode                      Description  ...  Revenue InvoiceDateDay
# InvoiceNo                                             ...
# 536381        71270                  PHOTO CLIP LINE  ...     1.25              1
# 536381        22262            FELT EGG COSY CHICKEN  ...     0.85              1
# 536381        22637            PIGGY BANK RETROSPOT   ...     2.55              1
# 536381        21166       COOK WITH WINE METAL SIGN   ...     1.95              1
# 536381       37444A  YELLOW BREAKFAST CUP AND SAUCER  ...     2.95              1
#
# [5 rows x 9 columns]
